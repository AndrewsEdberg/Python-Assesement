# %%
#This is the first programming
import csv
import logging

print("Welcome to the best matrimony website,Here you can find the best details")

filename="database.csv"
    
def InsertDetails():
    Name=input("Person name: ")
    Age=input("Age of the person: ")
    DOB=input("Enter the date of birth: ")
    Gender=input("Enter the gender Male/Female: ")
    Height=input("Enter the height of the person: ")
    Mothertounge=input("Enter your mothertounge: ")
    Languages=input("Enter the languages you've known: ")
    Qualification=input("Enter the qualification details of yours: ")
    

    with open(filename,'a',newline='') as file:
        csvwriter=csv.writer(file)
        csvwriter.csvwriterow([Name,Age,DOB,Gender,Height,Mothertounge,Languages,Qualification])
        
def modify():
    print("----------------------------------------------------------------")
    print("Updated!!")
    print("----------------------------------------------------------------")
    with open(filename,'a') as file:
        csvwriter=csv.writer(file)
        csvwriter.csvwriterow([Name,Age,DOB,Gender,Height,Mothertounge,Languages,Qualification])
        print("----------------------------------------------------------------")
        print("Updated!!")
        print("----------------------------------------------------------------")

def menu():
    print("0.Insertion")
    print("1.Modification")
    print("2.Retrieval")
    print("3.Searching")
    print("4.Recommendation")
    print("5.Deletion")
    print("9.Exit")
    choice=None
    try:
        choice=eval(input("Enter the Choice you want to: "))
    except:
        choice=logging.error(input("Enter the details is error"))
    return choice      
while True:
    choice==menu()
    if choice==0:
        InsertDetails()
    elif choice==1:
        Modify()
    elif choice==2:
        RetrieveData()
    elif choice==3:
        SearchDetails()
    elif choice==4:
        RecommendPerson()
    elif choice==5:
        DeleteDetails()
    elif choice==9:
        Exit
    else:
        break
# Out:
# Welcome to the best matrimony website,Here you can find the best details
# 0.Insertion
# 1.Modification
# 2.Retrieval
# 3.Searching
# 4.Recommendation
# 5.Deletion
# 9.Exit
# Enter the Choice you want to: 0
# Person name: Andrew2w
# Age of the person: 12
# Enter the date of birth: 213
# Enter the gender Male/Female: edeqwe
# Enter the height of the person: 221e
# Enter your mothertounge: 12
# Enter the languages you've known: wd
# Enter the qualification details of yours: wd
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-72270b8fed9f> in <module>
#      50     choice==menu()
#      51     if choice==0:
# ---> 52         InsertDetails()
#      53     elif choice==1:
#      54         Modify()
#
# <ipython-input-3-72270b8fed9f> in InsertDetails()
#      20     with open(filename,'a',newline='') as file:
#      21         csvwriter=csv.writer(file)
# ...

# %%
import csv
import logging
import random

print("Welcome to the best matrimony website,Here you can find the best details")

filename="database.csv"
    
def InsertDetails():
    ID=random.randint(1,50)
    print("Id",ID)
    U_ID=ID
    Name=input("Person name: ")
    Age=input("Age of the person: ")
    DOB=input("Enter the date of birth: ")
    Gender=input("Enter the gender Male/Female: ")
    Height=input("Enter the height of the person: ")
    Mothertounge=input("Enter your mothertounge: ")
    Qualification=input("Enter the qualification details of yours: ")
    

    with open(filename,'a',newline='') as file:
        csvwritter=csv.writer(file)
        csvwritter.writerow([U_ID,Name,Age,DOB,Gender,Height,Mothertounge,Qualification])
        print("----------------------------------------------------------------")
        print("Created!!")
        print("----------------------------------------------------------------")
        
        
def RetrieveData():
    print("U_ID\t\tName\t\tAge\t\tDOB\t\tGender\t\tHeight\t\tMothertounge\t\tQualification")
    with open(filename,'r') as file:
        data=csv.reader(file)
        for row in list(data):
            print(row[0],"\t\t",row[1],"\t\t",row[2],"\t\t",row[3],"\t\t",row[4],"\t\t",row[5],"\t\t",row[6],"\n")
        print("----------------------------------------------------------------")
        print("Retrieved!!")
        print("----------------------------------------------------------------")
def Searching():
    search=input("Enter to search anything: ")
    print("Search")
    print("----------------------------------------------------------------")
    print("U_ID\t\tName\t\tAge\t\tDOB\t\tGender\t\tHeight\t\tMothertounge\t\tQualification")
    print("----------------------------------------------------------------")
    with open(filename,'r') as file:
        data=csv.reader(file)
        details=list(data)
        search=[detailslist for detailslist in details if search in detailslist]
        if len(search)>0:
            for row in search:
                print(row[0],"\t\t",row[1],"\t\t",row[2],"t\t",row[3],"\t\t",row[4],"\t\t",row[5],"\t\t",row[6],"\n")
        else:
             print("-------------------------Not Found---------------------------------------")
            
def menu():
    print("0.Insertion")
    print("1.Modification")
    print("2.Retrieval")
    print("3.Searching")
    print("4.Recommendation")
    print("5.Deletion")
    print("9.Exit")
    choice=None
    try:
        choice=eval(input("Enter the Choice you want to: "))
    except:
        choice=logging.error(input("Enter the details is error"))
    return choice      
while True:
    choice=menu()
    if choice==0:
        InsertDetails()
    elif choice==1:
        Modify()
    elif choice==2:
        RetrieveData()
    elif choice==3:
        Searching()
    elif choice==4:
        RecommendPerson()
    elif choice==5:
        DeleteDetails()
    elif choice==9:
        Exit
    else:
        break
# Out:
# Welcome to the best matrimony website,Here you can find the best details
# 0.Insertion
# 1.Modification
# 2.Retrieval
# 3.Searching
# 4.Recommendation
# 5.Deletion
# 9.Exit
# Enter the Choice you want to: 3
# Enter to search anything: Andrews
# Search
# ----------------------------------------------------------------
# U_ID		Name		Age		DOB		Gender		Height		Mothertounge		Qualification
# ----------------------------------------------------------------
# -------------------------Not Found---------------------------------------
# 0.Insertion
# 1.Modification
# 2.Retrieval
# 3.Searching
# 4.Recommendation
# 5.Deletion
# 9.Exit
# Enter the Choice you want to: 0
# Id 30
# Person name: Andrews D Edberg
# Age of the person: 21
# Enter the date of birth: 03/01/2001
# Enter the gender Male/Female: Male
# Enter the height of the person: ^.0
# Enter your mothertounge: Tamil
# Enter the qualification details of yours: BE
# ----------------------------------------------------------------
# ...
